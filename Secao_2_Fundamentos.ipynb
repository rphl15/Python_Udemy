# %%
# 1 - Realize o print do seu nome completo, sua idade, e sua altura utilizando o print para cada valor
print("Raphael Camargo")
print("22 anos")
print("1,78")
# Out:
# Raphael Camargo
# 22 anos
# 1,78

# %%
''' 2 - Realize o print do seu nome completo, sua idade e sua altura
utilizando apenas um print para todos os valores.'''
print("Raphael Camargo, 22 anos, 1,78")
# Out:
# Raphael Camargo, 22 anos, 1,78

# %%
# 3 - Realize o print de 3 numeros de sua escolha em um mesmo print mas separados pelo caractere '-'
n1 = 23
n2 = 21
n3 = 45
print(f"{n1}-{n2}-{n3}")
#ou
print(23,21,45, sep="-")
# Out:
# 23-21-45
# 23-21-45

# %%
# 4 - Crie uma variável de cada tipo e ponha algum valor escolhido. Em seguida, printe todos esses valores
int = 12
float = 12.13
texto = "Texto"
booleano = True
print(f"{int}, {float}, {texto}, {booleano}")
# Out:
# 12, 12.13, Texto, True

# %%
''' 5 - Crie variáveis para guardar seu nome, CPF e uma que indique se você esta casado,
em seguida printe esses separadamente, mas não esqueça de printar junto que eles significam'''

nome = "Raphael Camargo"
cpf = 71871871820
casado = False
print(f"O meu nome é {nome}, meu cpf é: {cpf}, é casado? {casado}")
# Out:
# O meu nome é Raphael Camargo, meu cpf é: 71871871820, é casado? False

# %%
# 6 - Escreva e formate a data em que você nasceu no formato dia/mês/ano.
dia = 15
mes = 8
ano = 2003
if mes < 10:
    print(f"Eu nasci em {dia}/0{mes}/{ano}")
else:
    print(f"Eu nasci em {dia}/{mes}/{ano}")
# Out:
# Eu nasci em 15/08/2003

# %%
# 7 - Escreva e formate a hora e minuto atual
hora = 17
minuto = 4
if minuto < 10:
    print(f"Agora são {hora} horas e 0{minuto} minutos.")
else:
    print(f"Agora são {hora} horas e {minuto} minutos.")
# Out:
# Agora são 17 horas e 04 minutos.

# %%
''' 8 - Escreva um programa que contém o número PI, que deve ter o valor exato de 3.14159265359,
Formate esse número para ter apenas 5 casas decimais'''
pi = 3.14159265359
print(f"O número PI é: {pi:.5f}")
# Out:
# O número PI é: 3.14159

# %%
'''9 - Crie um programa que possui duas variáveis, uma recebe o ano em que estamos
e a outra o ano que voce nasceu. Em seguida subtraia ambas para receber uma estimativa de quantos você tem.'''
ano_nasc = 2003
ano_atual = 2026
estimativa = ano_atual - ano_nasc
print(f"A estimativa da sua idade é de: {estimativa}")
# Out:
# A estimativa da sua idade é de: 23

# %%
'''10 - Crie um programa que faz a media aritmética entre três números.
Estes números devem ser salvos em uma variável. Mostre esse valor na saida do programa.'''
num1 = 12
num2 = 12
num3 = 12
media = (num1 + num2 + num3) / 3
print(f"A media é de {media}")
# Out:
# A media é de 12.0

# %%
'''11 - Crie um progrma que calcule o IMC, o IMC é dado pelo peso KG divido pela altura em metros
elevado ao quadrado. Salvar eses valores em uma variável'''
altura = 1.77
peso = 86
imc = peso / (altura * altura)
print(f"O IMC é igual a {imc:.2f}")
# Out:
# O IMC é igual a 27.45

# %%
'''12 - Você tem um determinado números de ovos de páscoa para dividir entre um determinado
números de pessoas (duas variaveis iniciais). Determine quantos ovos ficarão por pessoa e quantos ovos sobrarão
pois não puderam ser divido igualmente. Lembre o número de ovos por pessoa é um número inteiro'''

ovos = 20
pessoas = 4

op = ovos // pessoas
sobra = ovos % pessoas

print(f'Cada pessoa recebe: {op}')
print(f'Sobram: {sobra}')
# Out:
# Cada pessoa recebe: 5
# Sobram: 0

# %%
'''13 - Crie um programa que diga "se você precisar ir ao mercado"
. Você precisa ir ao mercado se "Faltar comida" ou "se for sabado".
 Mostre na saida do programa o valor logico sim ou não'''

# %%
# Exercício 14
conta = "2400"
conversao = int(conta)
print(f'Você tem R${conversao - 1000}')
# Out:
# Você tem R$1400

# %%
# Exercício 15
altura = 1.77
conver = int(altura)
print(f'Sua altura é de {conver}')
# Out:
# Sua altura é de 1

# %%
# Exercício 16 
num1 = int(input('Digite um número: '))
num2 = int(input('Digite um número: '))
div = num1 / num2
print(f'O resultado é {div}')
# Out:
# O resultado é 9.0

# %%
# Exercício 17
dia = int(input('Digite o dia: '))
mes = int(input('Digite o mês: '))
ano = int(input('Digite o ano: '))
hora = int(input('Digite a hora: '))
minuto = int(input('Digite o minnuto: '))
segundo = int(input('Digite a segundo: '))
print(f"{dia}/{mes}/{ano} as {hora}:{minuto}:{segundo}")
# Out:
# 15/8/2003 as 18:15:42

# %%
# Exercício 18

media = int(input("Digite sua média: "))
nota_prova = int(input("Digite sua nota no exame: "))
if media >= 7 or nota_prova >= 5:
    print("Você foi aprovado")
else:
    print("Você foi reprovado")
# Out:
# Você foi reprovado

# %%
# Exercício 19

senha = 1234
insira = int(input("Digite a senha: "))
if insira == senha:
    print("Acesso liberado")
else:
    print("Acesso Negado!")
# Out:
# Acesso Negado!

# %%
# Exercício 20

# %%
# Exercício 21

# %%
# Exercício 22

# %%
# Exercício 23

# %%
# Exercício 24

# %%
# Exercício 25

# %%
# Exercício 26

# %%
# Exercício 27

# %%
# Exercício 28

# %%
# Exercício 29

# %%
# Exercício 30
